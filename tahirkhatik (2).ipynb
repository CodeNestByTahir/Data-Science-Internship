# %%
import pandas as pd

df1 = pd.read_csv(r"C:\Users\khati\Downloads\StudentsPerformance_with_headers.csv")
df2 = pd.read_csv(r"C:\Users\khati\Downloads\StudentsPerformance.csv")

print(df1.head())
print(df2.head())
# Out:
#   STUDENT ID  Student Age  Sex  Graduated high-school type  Scholarship type  \
# 0   STUDENT1            2    2                           3                 3
# 1   STUDENT2            2    2                           3                 3
# 2   STUDENT3            2    2                           2                 3
# 3   STUDENT4            1    1                           1                 3
# 4   STUDENT5            2    2                           1                 3
#
#    Additional work  Regular artistic or sports activity  \
# 0                1                                    2
# 1                1                                    2
# 2                2                                    2
# 3                1                                    2
# 4                2                                    2
#
#    Do you have a partner  Total salary if available  \
# 0                      2                          1
# 1                      2                          1
# ...

# %%
print(df1.info())
print(df2.info())

print(df1.describe())
print(df2.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 33 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   STUDENT ID                                                         145 non-null    object
#  1   Student Age                                                        145 non-null    int64
#  2   Sex                                                                145 non-null    int64
#  3   Graduated high-school type                                         145 non-null    int64
#  4   Scholarship type                                                   145 non-null    int64
#  5   Additional work                                                    145 non-null    int64
#  6   Regular artistic or sports activity                                145 non-null    int64
# ...

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (145, 33)
# (1000, 8)

# %% [markdown]
# <h1>dataset completion identification </h1><br>
# after seeing both datasets dataset2 (df2)is complete becouse there column names are understandable

# %%
print(df1.isnull().sum())
print(df2.isnull().sum())
# Out:
# STUDENT ID                                                           0
# Student Age                                                          0
# Sex                                                                  0
# Graduated high-school type                                           0
# Scholarship type                                                     0
# Additional work                                                      0
# Regular artistic or sports activity                                  0
# Do you have a partner                                                0
# Total salary if available                                            0
# Transportation to the university                                     0
# Accommodation type in Cyprus                                         0
# Mother’s education                                                   0
# Father’s education                                                   0
# ...

# %% [markdown]
# <h1>missing values</h1><br>
# </h1>no any dataset have null value

# %% [markdown]
# <h1>challenges faced</h1><br>no challnges this dataset are download from kaggle

# %%
<h1>after analysing both dataset df2 is better becouse it is understandable and it is very simple to undersstang
